# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns 
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df = pd.read_csv('hotel_reservations.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Understanding the Data
# It is essential to understand the dataset's data types and column names, selecting the relevant columns for the project, and identifying the null or missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
for i in df.describe(include = 'object'):
    print(i)
    print(df[i].unique())
    print('.'*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ....................................................................................................
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ....................................................................................................
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ....................................................................................................
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
null_count = df.isnull().sum()
print(null_count)
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ## Data Manipulation
# The next step is to manipulate and clean the data for data analysis which includes removing unncessary columns that have null values and correcting the data in the dataset.

# %%
df2 = df.drop(['agent', 'company'], axis = 1)
df2.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# ...

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df2.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df2['adr'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df2['days_in_waiting_list'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df2 = df2[df2['adr']<5400]
df2.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df2['adr'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## Data Analysis and Visualisation
# The cleaned and processed dataframe will be analysed and visualised using matplotlib and seaborn.

# %%
cancellation_rate = df2['is_canceled'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
cancellation_rate
# Out:
# 0    62.9%
# 1    37.1%
# Name: is_canceled, dtype: object

# %%
resort_hotel_rate = df2[df2['hotel'] == 'Resort Hotel']
resort_hotel_rate['is_canceled'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0    72.0%
# 1    28.0%
# Name: is_canceled, dtype: object

# %%
city_hotel_rate = df2[df2['hotel'] == 'City Hotel']
city_hotel_rate['is_canceled'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0    58.3%
# 1    41.7%
# Name: is_canceled, dtype: object

# %%
sns.set(style='darkgrid')

plt.figure(figsize=(6, 4))
ax = sns.countplot(x='is_canceled', data=df2, palette='dark')
plt.title('Bookings Status Count', fontsize=18)
plt.xlabel('Cancellation Status', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks([0, 1], ['Not Cancelled', 'Cancelled'], fontsize=12)
plt.show()

# %%
plt.figure(figsize= (8,4))
ax1 = sns.countplot(x='hotel', hue='is_canceled',data = df2, palette = 'dark')
legend_labels,_= ax1.get_legend_handles_labels()
plt.title('Booking Statuses in City and Resort Hotels')
plt.xlabel('Hotel')
plt.ylabel('Reservations')
plt.legend(['Not Cancelled', 'Cancelled'])
plt.show()

# %%
resort_hotel_rate = resort_hotel_rate.groupby('reservation_status_date')[['adr']].mean()
city_hotel_rate = city_hotel_rate.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize= (14,8))
plt.title('Average Daily Rate (ADR) in City and Resort Hotels', fontsize=20)
plt.plot(resort_hotel_rate.index, resort_hotel_rate['adr'], label='Resort Hotel')
plt.plot(city_hotel_rate.index, city_hotel_rate['adr'], label='City Hotel')
plt.legend(fontsize=16)
plt.show()

# %%
df2['month'] = df2['reservation_status_date'].dt.month
plt.figure(figsize=(14,8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df2, palette='deep')
legend_labels,_= ax1.get_legend_handles_labels()
plt.title('Booking Status (Month Wise)', fontsize=20)
plt.xlabel('Month')
plt.ylabel('Reservations')
plt.legend(['Not Cancelled', 'Cancelled'], fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(pd.crosstab(df2.arrival_date_month,df2.hotel), annot=True, fmt='d', cmap='coolwarm')

plt.title('Hotel Bookings by Arrival Month', fontsize=18)
plt.xlabel('Hotel', fontsize=14)
plt.ylabel('Arrival Month', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
cancelled_data = df2[df2['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()

# %%
plt.figure(figsize=(14,8))
plt.title('Average Daily Rate(ADR) per Month', fontsize=20)
sns.barplot(x='month', y='adr', data=cancelled_data, palette='deep')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.show()

# %%
repeated_guest_df = df2[df2['is_repeated_guest']==1]
non_repeated_guest_df = df2[df2['is_repeated_guest']==0]

repeated_guest_cancel_counts = repeated_guest_df.groupby('is_canceled')['is_canceled'].count().reset_index(name='Count')
non_repeated_guest_cancel_counts = non_repeated_guest_df.groupby('is_canceled')['is_canceled'].count().reset_index(name='Count')

plt.figure(figsize=(8, 6))
sns.barplot(x='is_canceled', y='Count', data=repeated_guest_cancel_counts, palette='deep')
plt.xlabel('Cancellation Status')
plt.ylabel('Count of Bookings')
plt.title('Cancellations for Repeated Guests')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='is_canceled', y='Count', data=non_repeated_guest_cancel_counts, palette='deep')
plt.xlabel('Cancellation Status')
plt.ylabel('Count of Bookings')
plt.title('Cancellation Status for Non-Repeated Guests')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %%
df_below_24 = df2[df2['lead_time'] < 24]
df_above_24 = df2[df2['lead_time'] >= 24]

cancelled_below_24 = df_below_24['is_canceled'].sum()
cancelled_above_24 = df_above_24['is_canceled'].sum()

plt.figure(figsize=(6, 4))
sns.barplot(x=['Lead Time <24 Days', 'Lead Time >24 Days'], y=[cancelled_below_24, cancelled_above_24], palette='deep')
plt.title('Bookings Cancellation Comparison by Lead Time', fontsize=16)
plt.xlabel('Lead Time', fontsize=14)
plt.ylabel('Number of Cancellations', fontsize=14)
plt.show()

# %%
lead_time = df2.groupby('arrival_date_month')[['lead_time']].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.plot(lead_time['arrival_date_month'], lead_time['lead_time'], 'ro')
plt.title('Average Lead Time by Month', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Lead Time (Days)', fontsize=14)
plt.show()

# %%
wait_list = df2.groupby('arrival_date_month')['days_in_waiting_list'].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.plot(wait_list['arrival_date_month'], wait_list['days_in_waiting_list'], 'ro')
plt.title('Average Days in Waitlist by Month', fontsize=18)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Days in Waitlist', fontsize=14)
plt.show()

# %%
cancelled_data = df2[df2['is_canceled'] == 1]

# %%
country = df2['country'].unique()
country
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
cancellation_by_country = cancelled_data['country'].value_counts()
cancellation_by_country
# Out:
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
#        ...
# UMI        1
# HND        1
# FJI        1
# SYC        1
# CRI        1
# Name: country, Length: 127, dtype: int64

# %%
cancellation_by_country = cancelled_data['country'].value_counts()[:5]

# %%
plt.figure(figsize=(5,10))
plt.title('Cancellation Rate by Country (Top 5)')
plt.pie(cancellation_by_country, autopct='%.1f%%', labels = cancellation_by_country.index)
plt.show()

# %%
market_segment = df2['market_segment'].unique()
market_segment
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Aviation'], dtype=object)

# %%
market_segment = df2['market_segment'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
market_segment
# Out:
# Online TA        47.4%
# Offline TA/TO    20.3%
# Groups           16.7%
# Direct           10.5%
# Corporate         4.3%
# Complementary     0.6%
# Aviation          0.2%
# Name: market_segment, dtype: object

# %%
cancelled_data['market_segment'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# Online TA        47.0%
# Groups           27.4%
# Offline TA/TO    18.7%
# Direct            4.3%
# Corporate         2.2%
# Complementary     0.2%
# Aviation          0.1%
# Name: market_segment, dtype: object

# %%
not_cancelled_data = df2[df2['is_canceled'] == 0]

# %%
cancelled_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_adr.reset_index(inplace = True)
cancelled_adr.sort_values('reservation_status_date', inplace = True)

not_cancelled_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_adr.reset_index(inplace = True)
not_cancelled_adr.sort_values('reservation_status_date', inplace = True)

# %%
plt.figure(figsize=(20,10))
plt.title('Average Daily Rate Comparison', fontsize=30)
plt.plot(not_cancelled_adr['reservation_status_date'],not_cancelled_adr['adr'], label = 'Not Cancelled')
plt.plot(cancelled_adr['reservation_status_date'],cancelled_adr['adr'], label = 'Cancelled')
plt.legend(loc='best',fontsize = 20)
plt.show()

# %%
cancel_cor = df2.corr()['is_canceled']
cancel_cor
# Out:
# is_canceled                       1.000000
# lead_time                         0.292004
# arrival_date_year                 0.016415
# arrival_date_week_number          0.007477
# arrival_date_day_of_month        -0.006138
# stays_in_weekend_nights          -0.002621
# stays_in_week_nights              0.024119
# adults                            0.058379
# children                          0.004754
# babies                           -0.032520
# is_repeated_guest                -0.085178
# previous_cancellations            0.109924
# previous_bookings_not_canceled   -0.055493
# booking_changes                  -0.144674
# days_in_waiting_list              0.054018
# adr                               0.047294
# required_car_parking_spaces      -0.194795
# total_of_special_requests        -0.235638
# month                            -0.046097
# Name: is_canceled, dtype: float64

# %% [markdown]
# # Developing a Machine Learning Model

# %%
df2.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

X = df2.drop('is_canceled', axis=1) 
y = df2['is_canceled']

numerical_features = ['lead_time', 'arrival_date_week_number',
                      'arrival_date_day_of_month', 'stays_in_weekend_nights', 
                      'stays_in_week_nights', 'adults', 'children', 'babies', 
                      'is_repeated_guest', 'previous_cancellations', 
                      'previous_bookings_not_canceled', 'adr', 'required_car_parking_spaces', 
                      'total_of_special_requests']

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_features = ['hotel', 'arrival_date_month', 'meal', 
                        'market_segment', 'distribution_channel', 
                        'reserved_room_type', 
                        'deposit_type', 'customer_type']

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

X_preprocessed = preprocessor.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

accuracy = rf_classifier.score(X_test, y_test)
print("Test Set Accuracy:", accuracy)
# Out:
# Test Set Accuracy: 0.8597140454163162

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

params = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
    'bootstrap': bootstrap
}

rf_classifier2 = RandomForestClassifier()

random_search = RandomizedSearchCV(
    rf_classifier2, param_distributions=params,
    n_iter=10, cv=5, scoring='accuracy', n_jobs=-1, random_state=42
)
random_search.fit(X_train, y_train)

best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

rf_classifier2 = random_search.best_estimator_
y_pred = rf_classifier2.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Test Set Accuracy:", accuracy)
# Out:
# Best Hyperparameters: {'n_estimators': 76, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': False}
# Test Set Accuracy: 0.8613961312026913
